# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman811630/-EDA-on-Play-Store-App-Reviews-Data-Sets/blob/main/Aman_Singh_EDA_on_Play_Store_App_Review_Dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -----
#
#
# -----
#
#
#
# # **Project Name**    - Play Store App Review Analysis  ![google-play-png-logo-3783.png](data:image/png;base64,...)
#
#
#
#
# -----
# -----

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Team Member 1 -** Aman Singh.
# ##### **Team Member 2 -** Amit Kumar.
# ##### **Team Member 3 -** Bhawesh Chandravanshi.
# ##### **Team Member 4 -** Shashank Rajput.
# ##### **Team Member 5 -** Vaibhav Dwivedi.

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Our project based on EDA (Exploratort Data Analysis) type and we are using Google Play Store App Review dataset to EDA.
# Here we are using Python language to do operation and also import some important libraries such as Pandas for data analysis and Matplotlib for data visulization etc. Our main Objective is to discover key factors reposible for App engagement and success.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Aman811630/-EDA-on-Play-Store-App-Reviews-Data-Sets

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Our Problem Statement is that " We have to identify that in which category and which application is mostly installed by users AND also according to reviews and rating too " ?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime,date

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path_1="/content/drive/MyDrive/Play Store Data.csv"
file_path_2="/content/drive/MyDrive/User Reviews.csv"

# %%
play_store_app_df=pd.read_csv(file_path_1)

# %%
user_reviews_df=pd.read_csv(file_path_2)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

play_store_app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
play_store_app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
play_store_app_df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
user_reviews_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
user_reviews_df.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
# Copy the play_store app dataset to app_df
app_df=play_store_app_df.copy()
app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Copy the user reviews df dataset to reviews_df
reviews_df=user_reviews_df.copy()
reviews_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
reviews_df.size
# Out:
# 321475

# %%
app_df.size
# Out:
# 140933

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
app_df.shape
# Out:
# (10841, 13)

# %% [markdown]
# We have 10841 rows and 13 columns in our app_df.

# %%
reviews_df.shape
# Out:
# (64295, 5)

# %% [markdown]
# We have 64295 rows and 5 columns in our reviews_df.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# ###<b>`1. For Play Store App dataset`

# %% [markdown]
# #### Duplicate Values

# %%
# Number of duplicated rows.
# df.duplicated().sum() function counts no of duplicate rows in a dataframe.
app_df.duplicated().sum()
# Out:
# 483

# %%
# Now, removing duplicate rows
app_df.drop_duplicates(inplace=True)
app_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
app_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
app_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
app_df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10358    10358  8893.000000   10358               10358       10358
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1943          NaN     593                1526        1488
# mean       NaN      NaN     4.189542     NaN                 NaN         NaN
# std        NaN      NaN     0.545452     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * App : Name of the Applications.
#
# * Category : the category of Application.
#
# * Rating : Rating given by the user.
#
# * Reviews : number of reviws given by user.
#
# * Size : size of the application.
#
# * installs : how many time the App is install by user.
#
# * Type : Application is free or paid.
#
# * Price : price of the Apps.
#
# * Content_Rating : 	Rating given by different Age group.
#
# * Genres : different genres of the Appplication.
#
# * Last_Updated : date of last update oof the Apps.
#
# * Current_Ver	: current version of the Apps.
#
# * Android_Ver	: android versio  supported the Apps.
#
# * Translated_Review : reviews weitten by the user about the Apps.
#
# * Sentiment : sentiment of user Positive or Negative.
#
# * Sentiment_Polarity : sentiments in numeric format.
#
# * Sentiment_Subjectivity :  the degree to which a person is personally involved towards App.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in app_df.columns.tolist():
  print("No. of unique values in ",i,"is",app_df[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 6002 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 120 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2832 .
# No. of unique values in  Android Ver is 33 .

# %% [markdown]
# ## 3. ***Data Cleaning and Data Wrangling***

# %% [markdown]
# ###Play store data set :

# %% [markdown]
# ###<b>`Rating`

# %%
app_df["Rating"].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
# we have to  replace outlier 19. and nan with average ratings.

app_df['Rating'].replace(np.nan, round(app_df['Rating'].mean(),1),inplace=True)
app_df['Rating'].replace(19.,round(app_df['Rating'].mean(),1),inplace=True)

# %%
app_df["Rating"].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
app_df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### <b> `Size`

# %%
app_df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
app_df[app_df["Size"]=='Varies with device'].value_counts().sum()
# Out:
# 1525

# %%
# '1,000+' is a value in one row of column 'Size', remove this row from df_1

x=app_df[app_df['Size']=='1,000+'].index
app_df.drop(axis=0, inplace=True, index=x)

# %%
# define a function to remove the last letter from size
def remove_end_letter(size):
  if size[-1]=='M':
    size=size[:-1]
    return float(size)
  elif size[-1]=='k':
    return float(size[:-1])/1000
  else:
    return 0.0

# %%
app_df.Size=app_df.Size.apply(remove_end_letter)

# %%
# Replacing the 0.0 value with mean values
app_df['Size']=app_df['Size'].replace(0.0,app_df['Size'].mean())

# %% [markdown]
# ###<b> `Reviews`

# %%
# reviews data contains some values in  Million format such as 200M,100M,etc so we need to convert it in numeric by using ( 1M =1000000)
app_df['Reviews']=pd.to_numeric(app_df['Reviews'],errors='coerce')

# %% [markdown]
# ### <b> `Installs`

# %%
app_df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
# replacing + , from installs columns
app_df.Installs=app_df.Installs.apply(lambda x : x.replace(',','') if ',' in x else x)
app_df.Installs=app_df.Installs.apply(lambda x : x.replace('+','') if '+' in x else x)
app_df.Installs=app_df.Installs.astype(int)

# %% [markdown]
# ### <b> `Price`

# %%
app_df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
# replacing $ sign from price  column

app_df['Price']=app_df['Price'].apply(lambda x: str(x).replace('$','') if '$' in str(x) else str(x))
app_df['Price']=app_df['Price'].apply(lambda x: float(x))

# %% [markdown]
# ###<b>`1. For User Reviews dataset`

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
reviews_df.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# droping nan value 
reviews_df=reviews_df.dropna()

# %%
reviews_df.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37427 entries, 0 to 64230
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37427 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37427 non-null  object
#  3   Sentiment_Polarity      37427 non-null  float64
#  4   Sentiment_Subjectivity  37427 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %%
reviews_df.shape
# Out:
# (37427, 5)

# %% [markdown]
# We have 37427 rows and 5 columns in our reviews data set.

# %%
reviews_df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37427.000000            37427.000000
# mean             0.182171                0.492770
# std              0.351318                0.259904
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ## <b> Joined Both the Dataset by using (Inner Join)

# %%
combined_df=pd.merge(app_df,reviews_df, how='inner', on=['App'])

# %%
combined_df.head()
# Out:
#                    App        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
#
#    Price Content Rating                     Genres      Last Updated  \
# 0    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# ...

# %%
combined_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59163 entries, 0 to 59162
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     59163 non-null  object
#  1   Category                59163 non-null  object
#  2   Rating                  59163 non-null  float64
#  3   Reviews                 59163 non-null  int64
#  4   Size                    59163 non-null  float64
#  5   Installs                59163 non-null  int64
#  6   Type                    59163 non-null  object
#  7   Price                   59163 non-null  float64
#  8   Content Rating          59163 non-null  object
#  9   Genres                  59163 non-null  object
#  10  Last Updated            59163 non-null  object
#  11  Current Ver             59163 non-null  object
#  12  Android Ver             59163 non-null  object
#  13  Translated_Review       59163 non-null  object
# ...

# %%
combined_df.describe()
# Out:
#              Rating       Reviews          Size      Installs         Price  \
# count  59163.000000  5.916300e+04  59163.000000  5.916300e+04  59163.000000
# mean       4.341323  2.766230e+06     29.685470  8.102117e+07      0.071689
# std        0.274036  7.140035e+06     24.487507  1.955213e+08      1.025769
# min        2.600000  1.000000e+01      0.008500  1.000000e+03      0.000000
# 25%        4.200000  2.567100e+04     18.151246  1.000000e+06      0.000000
# 50%        4.400000  2.498550e+05     18.151246  1.000000e+07      0.000000
# 75%        4.500000  1.873523e+06     41.000000  1.000000e+08      0.000000
# max        4.900000  7.815831e+07     99.000000  1.000000e+09     29.990000
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        59163.000000            59163.000000
# mean             0.155526                0.495952
# std              0.331987                0.238741
# min             -1.000000                0.000000
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
# App Type Distribution
b=app_df['Type'].value_counts()
b
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %% [markdown]
# #### Chart - 1

# %%
# ploting pie chart of type of apps

colors=['#ff9999','#66b3ff']
plt.pie(b,labels=['Free','Paid'],autopct='%1.2f%%',colors=colors ,shadow=True)
plt.title('App Type Distribution');

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
#
# The above  pie chart shows that in our dataset numbers of Free apps is much more as compared to Paid apps.

# %% [markdown]
# ### Chart - 2

# %%
# Numbers of Free and Paid apps in Different Category

plt.figure(figsize=(15,7))
sns.countplot(x='Category',hue='Type',data=app_df)


plt.xticks(rotation=90,horizontalalignment='right');

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation**:
#
# The above graph shows that most of the free and paid apps are from  Family and Game category.

# %% [markdown]
# ## `Top 10 app categories by installations`

# %%
top10_category=app_df.groupby(['Category']).agg({'Installs':np.sum}).sort_values('Installs',ascending=False)[:10]
top10_category.sort_values('Installs',ascending=False)

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# #### Chart - 3

# %%
# Top 10 categories by installation
sns.set(style='darkgrid')
a=sns.barplot(y=top10_category.index,x='Installs',data=top10_category,orient='h')
xlabels = ['{:,.0f}'.format(x) + 'B' for x in a.get_xticks()/1000000000]
a.set_xticklabels(xlabels)
plt.title('Top 10 categories by installation')
plt.show()

images_dir='/content/drive/MyDrive/EDA Capston Project'
# Out:
# <ipython-input-56-307b04a85433>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   a.set_xticklabels(xlabels)

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:** The above graph shows that top 5 app categories by installations are game, communication,social,productivity,tools respectively.

# %% [markdown]
# ### `Top 5 App in each Category by installation:`
# This would help in detrmining potential categorty to enter in for apps making. Top five apps in each category would helps us to identify our competitors.

# %% [markdown]
# #### Chart - 4

# %%
# Top 5 GAME app

fig = plt.figure() 
plt.figure(figsize=(15,8))
import matplotlib.ticker as ticker
ax = fig.add_subplot(111) 
ax2 = ax.twinx() 

width = 0.4
top5game_app_by_install=app_df[app_df['Category']=='GAME'].groupby(['App']).agg({'Installs':np.sum,'Reviews':np.sum}).sort_values('Installs',ascending=False).head()
top5game_app_by_install.Installs.plot(kind='bar', color='green', ax=ax, width=width, position=1)
top5game_app_by_install.Reviews.plot(kind='bar', color='salmon', ax=ax2, width=width, position=0)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000000) + 'M'))
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))

ax.set_ylabel('Installs')
ax.set_title('Top 5 apps in Game category')
ax2.set_ylabel('Reviews')
ax.legend()
plt.show()

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:** Subway Surfers app  is on top in the game category by installations and reviews.

# %% [markdown]
# #### Chart - 5

# %%
# Top 5 Social app

fig = plt.figure() 
plt.figure(figsize=(15,8))

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4
top5Social_app_by_install=app_df[app_df['Category']=='SOCIAL'].groupby(['App']).agg({'Installs':np.sum,'Reviews':np.sum}).sort_values('Installs',ascending=False).head()
top5Social_app_by_install.Installs.plot(kind='bar', color='green', ax=ax, width=width, position=1)
top5Social_app_by_install.Reviews.plot(kind='bar', color='salmon', ax=ax2, width=width, position=0)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000000) + 'M'))
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))

ax.set_ylabel('Installs')
ax.legend()
ax.set_title('Top 5 apps in Social category')
ax2.set_ylabel('Reviews')

plt.show()

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
#
# Instagram app  is on top in the Social category by installations and reviews.

# %% [markdown]
# #### Chart - 6

# %%
# Top 5 PRODUCTIVITY app

fig = plt.figure() # Create matplotlib figure
plt.figure(figsize=(15,8))

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4
top5PRODUCTIVITY_app_by_install=app_df[app_df['Category']=='PRODUCTIVITY'].groupby(['App']).agg({'Installs':np.sum,'Reviews':np.sum}).sort_values('Installs',ascending=False).head()
top5PRODUCTIVITY_app_by_install.Installs.plot(kind='bar', color='green', ax=ax, width=width, position=1)
top5PRODUCTIVITY_app_by_install.Reviews.plot(kind='bar', color='salmon', ax=ax2, width=width, position=0)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000000) + 'M'))
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))

ax.set_ylabel('Installs')
ax.set_title('Top 5 apps in productivity category')
ax2.set_ylabel('Reviews')
ax.legend()

plt.show()

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
#
# Google drive app  is on top in the productivity category by installations and reviews.

# %% [markdown]
# #### Chart - 7

# %%
# Top 5 FAMILY app

fig = plt.figure() 
plt.figure(figsize=(15,8))

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4
top5FAMILY_app_by_install=app_df[app_df['Category']=='FAMILY'].groupby(['App']).agg({'Installs':np.sum,'Reviews':np.sum}).sort_values('Installs',ascending=False).head()
top5FAMILY_app_by_install.Installs.plot(kind='bar', color='green', ax=ax, width=width, position=1)
top5FAMILY_app_by_install.Reviews.plot(kind='bar', color='salmon', ax=ax2, width=width, position=0)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000000) + 'M'))
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))

ax.set_ylabel('Installs')
ax.set_title('Top 5 apps in family category')
ax2.set_ylabel('Reviews')
ax.legend()

plt.show()

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
#
# Google Play Games app  is on top in the family category by installations and reviews.

# %% [markdown]
# #### Chart - 8

# %%
#top 5 apps in PHOTOGRAPHY

top5PHOTOGRAPHY_app_by_install=app_df[app_df['Category']=='PHOTOGRAPHY'].groupby(['App']).agg({'Installs':np.sum}).sort_values('Installs',ascending=False).head()

top5PHOTOGRAPHY_app_by_install.sort_values('Installs').plot(kind='barh', color="salmon")

plt.xlabel('No of Installations')
plt.ylabel('Apps')
plt.title('Top 5 apps in Photography category');

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
# Google Photos app  is on top in the Photography category by installations.

# %% [markdown]
# #### Chart - 9

# %%
#top10 apps by install


top10_apps_by_install=app_df.groupby(['App']).agg({'Installs': np.mean}).sort_values('Installs',ascending=False).head(10)


top10_apps_by_install.sort_values('Installs', ascending=False).plot.barh(color ='salmon')
plt.xlabel('Reviews')
plt.title('Top 10 apps by reviews')
plt.show()

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
#
# Google Play Books  is the top most installed app in all category.

# %% [markdown]
# #### Chart - 10

# %%
# top10 apps by reviews

# We observed that some apps have many entries having defferent reviews. So, now group by on apps and aggregate on reviews to obtain single entry.

top10_apps_by_reviews=app_df.groupby(['App']).agg({'Reviews': np.mean}).sort_values('Reviews',ascending=False).head(10)


top10_apps_by_reviews.sort_values('Reviews').plot.barh(color ='salmon')
plt.xlabel('Reviews')
plt.title('Top 10 apps by reviews')
plt.show()

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
#
# Facebook app  is the most reviwed app in all category.

# %% [markdown]
# #### Chart - 11

# %%
#  Distribution of Rating

app_df['Rating'].value_counts().plot(kind="bar",figsize=(15,5),edgecolor='black',colormap='Spectral')
ax.set_facecolor('bisque')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show();

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
#
# *   Most of the apps have ratings in the range of  3.8 to 4.8
# *   4.2 rating is given by more than 2500 people.

# %% [markdown]
# #### Chart - 12

# %%
# number of install in each catgeory

categories=app_df.groupby('Category')

m=categories[['Installs']].sum().reset_index()

plt.figure(figsize=(15,7))
sns.barplot(x='Category',y='Installs',data=m)

ax.set_facecolor('bisque')
plt.xticks(rotation=90)
plt.ylabel('Installs ( Billions)')
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000000000) + 'B'))
plt.title('Number of Installs for each Category')
plt.show()

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation**
#
# *   Most of the apps being downloaded and installed are from the categories of **Game** and **Communication**.
# *   Categories of least downloaded app are **Parenting**, **Events** and **Beauty**.

# %% [markdown]
# #### Chart - 13

# %%
# Distribution of rating vs price

sns.scatterplot(data=app_df, x="Price", y="Rating",hue='Type')

images_dir='/content/drive/MyDrive/EDA Capston Project'

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation**:
#
# The above scatter plot shows that most of the paid apps ratings are clustered in range of 3.5-5.

# %% [markdown]
# #### Chart - 14

# %%
# Reviews sentiment distribution
seniment=combined_df['Sentiment'].value_counts()

plt.pie(seniment,labels=['Positive','Neutral','Negative'],autopct='%1.2f%%',shadow=True,colors=['salmon','plum','yellow'])
plt.title('Reviews sentiment distribution ');

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation**:
#
#  The above pie chart shows that 63.48 % reviews is positive and 25.43 % reviews is neutral and 11.09% reviews is negative

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.barplot(data=combined_df, x="Content Rating", y="Rating",hue='Sentiment')
# Out:
# <Axes: xlabel='Content Rating', ylabel='Rating'>

# %% [markdown]
# #### Chart - 15 - Heat Map

# %%
# forming a Correalation Matrix
app_df.corr()
# Out:
# <ipython-input-69-2aff617c50dd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   app_df.corr()
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.068068  0.068411  0.050128 -0.020509
# Reviews   0.068068  1.000000  0.122138  0.634997 -0.009417
# Size      0.068411  0.122138  1.000000  0.070453 -0.022581
# Installs  0.050128  0.634997  0.070453  1.000000 -0.011147
# Price    -0.020509 -0.009417 -0.022581 -0.011147  1.000000

# %%
# Plotting A heatmap
sns.heatmap(app_df.corr(),cmap="RdBu",linewidth=1,annot=True,)
# Out:
# <ipython-input-70-8130bb9648d6>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(app_df.corr(),cmap="RdBu",linewidth=1,annot=True,)
# <Axes: >

# %% [markdown]
# #####  What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
#
# *  Apps Installs and Reviews are 63 % positively correlated.
# *  App Size is 23 % negatively correlated.

# %% [markdown]
# PLotting a Combine plot to get a  Rating overview on app_df dataset columns ("Reivews" ,"Size" ,"Installs", " Price" ).

# %%
# plot the graphs of reviews, size, installs and price per rating

combine_plot = app_df.groupby('Rating').sum().reset_index()

fig, axes = plt.subplots(1, 4, figsize=(14, 4))

axes[0].plot(combine_plot['Rating'], combine_plot['Reviews'], 'r')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('Reviews Per Rating')



axes[1].plot(combine_plot['Rating'], combine_plot['Size'], 'g')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Size')
axes[1].set_title('Size Per Rating')


axes[2].plot(combine_plot['Rating'], combine_plot['Installs'], 'g')
axes[2].set_xlabel('Rating')
axes[2].set_ylabel('Installs (e+10)')
axes[2].set_title('Installs Per Rating')


axes[3].plot(combine_plot['Rating'], combine_plot['Price'], 'b')
axes[3].set_xlabel('Rating')
axes[3].set_ylabel('Price')
axes[3].set_title('Price Per Rating')


plt.tight_layout(pad=2)
plt.show()

images_dir='/content/drive/MyDrive/EDA Capston Project'
# Out:
# <ipython-input-71-7f42c78d2140>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   combine_plot = app_df.groupby('Rating').sum().reset_index()

# %% [markdown]
# Here we can  see that Rating effect on different columns of data set.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **After performing the Eda on our Play Store App  and Reviews Data set we conculde the following point:**
#
# 1. Apps of the Categories like Game, Communication , Social and Productivity are very highly downloaded by the users .These categories are the areas where our client get more customers so work in upadating the apps and producing more apps of this categories  will surely more benefit for the Client.
#
# 2. As it can be easily seen by our customer Rating and Sentiment section analysis ,our customer installs the apps and provide mostly high rating and positive reviews.
#
# 3. On analaysis we found Social apps such as Facebook, Instagram, and WhatsApp are most liked app whereas Subway surfer, Google Photos, Handouts, Instagram are among most installed apps.
#
# 4. It is found that average rating of the apps is around 4.2. Maximum number of sentiment subjectivity lies between 0.4 and 0.7 showing that users have given reviews according to their experience.

# %% [markdown]
# # ***Hurrah! We have successfully completed Our EDA Capstone Project !!!***
